# %%
import os
import sys

from moredata.enricher import EnricherBuilder, Enricher
from moredata.enricher.sql_connector import SqlConnector
from moredata.models.data import JsonData, GeopandasData
from moredata.parser import parse_document
from moredata.utils import read_json_from_file, Converter, write_json_generator_to_json
from moredata.datasets import get_path

# %%
import pandas as pd

df = pd.read_csv(get_path("airbnb-berlin-main"))
df = df.loc[(~df['latitude'].isna()) & (~df['longitude'].isna())]

df.iloc[0:100].to_json('./data/airbnb-berlin.json', orient='records')

# %%
from sqlalchemy import create_engine
URL = "mysql+pymysql://root:root@localhost:3306/moredata"
engine = create_engine(URL, echo=False)

extra = pd.read_csv(get_path("airbnb-berlin-extra"))
extra.to_sql('extra', con=engine, if_exists='replace')
# Out:
# 19859

# %%
pd.read_sql('SELECT id, amenities, accommodates, beds, bedrooms FROM extra', engine)
# Out:
#              id                                          amenities  \
# 0          1944  ["Dishes and silverware", "Kitchen", "Oven", "...
# 1          2015  ["Smoke alarm", "Cooking basics", "Lockbox", "...
# 2          3176  ["Dedicated workspace", "Hangers", "Kitchen", ...
# 3          3309  ["Host greets you", "Washer", "Hangers", "Hot ...
# 4          6883  ["Smoke alarm", "Cooking basics", "Dishes and ...
# ...         ...                                                ...
# 19854  48597066  ["Dedicated workspace", "Hangers", "Private en...
# 19855  48599795  ["Hot water kettle", "Dryer", "Hangers", "Hot ...
# 19856  48600069  ["Air conditioning", "Hot water", "Elevator", ...
# 19857  48602039  ["Dedicated workspace", "Hangers", "Kitchen", ...
# 19858  48615659  ["Dedicated workspace", "Hangers", "Kitchen", ...
#
#        accommodates  beds bedrooms
# 0               1.0   1.0      1.0
# 1               3.0   0.0      1.0
# 2               4.0   2.0      1.0
# 3               1.0   1.0      1.0
# 4               2.0   1.0      1.0
# ...             ...   ...      ...
# 19854           2.0   1.0      1.0
# 19855           2.0   1.0      1.0
# 19856           1.0   1.0      1.0
# 19857           1.0   NaN      1.0
# 19858           2.0   NaN      1.0
#
# [19859 rows x 5 columns]

# %%
data = JsonData(data_file='./data/airbnb-berlin.json', parser=parse_document)

sql_enricher = Enricher(connector=SqlConnector(connection_url=URL, table_name="extra", column='id', result_attr="extra", dict_keys=["id"]))

data_enriched = sql_enricher.enrich(data)

write_json_generator_to_json("./data/airbnb-berlin-enriched", data_enriched, 100000)

# %%
#Geopandas
gdf = pd.read_csv(get_path("airbnb-berlin-main"))
gdf = gdf.loc[(~gdf['latitude'].isna()) & (~gdf['longitude'].isna())]
airbnb = GeopandasData().from_geodataframe(gdf.iloc[0:100])

sql_enricher = Enricher(connector=SqlConnector(connection_url=URL, 
table_name="extra", column='id', result_attr="extra", dict_keys=["id"], df_column='id'))

data_enriched = sql_enricher.enrich(airbnb)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/kali/github/more-data/examples/sql_connector/sql-airbnb.ipynb Cell 6' in <cell line: 9>()
#       <a href='vscode-notebook-cell:/home/kali/github/more-data/examples/sql_connector/sql-airbnb.ipynb#ch0000008?line=3'>4</a> airbnb = GeopandasData().from_geodataframe(gdf.iloc[0:100])
#       <a href='vscode-notebook-cell:/home/kali/github/more-data/examples/sql_connector/sql-airbnb.ipynb#ch0000008?line=5'>6</a> sql_enricher = Enricher(connector=SqlConnector(connection_url=URL,
#       <a href='vscode-notebook-cell:/home/kali/github/more-data/examples/sql_connector/sql-airbnb.ipynb#ch0000008?line=6'>7</a> table_name="extra", column='id', result_attr="extra", dict_keys=["id"]))
# ----> <a href='vscode-notebook-cell:/home/kali/github/more-data/examples/sql_connector/sql-airbnb.ipynb#ch0000008?line=8'>9</a> data_enriched = sql_enricher.enrich(airbnb)
#
# File ~/github/more-data/moredata/enricher/enricher.py:49, in Enricher.enrich(self, data, **kwargs)
#      <a href='file:///home/kali/github/more-data/moredata/enricher/enricher.py?line=35'>36</a> def enrich(self, data, **kwargs):
#      <a href='file:///home/kali/github/more-data/moredata/enricher/enricher.py?line=36'>37</a>     """Call enrich function of interface :obj:`IEnricherConnector`
#      <a href='file:///home/kali/github/more-data/moredata/enricher/enricher.py?line=37'>38</a>
#      <a href='file:///home/kali/github/more-data/moredata/enricher/enricher.py?line=38'>39</a>     Parameters
#    (...)
#      <a href='file:///home/kali/github/more-data/moredata/enricher/enricher.py?line=46'>47</a>
#      <a href='file:///home/kali/github/more-data/moredata/enricher/enricher.py?line=47'>48</a>     """
# ---> <a href='file:///home/kali/github/more-data/moredata/enricher/enricher.py?line=48'>49</a>     return self._connector.enrich(data, **kwargs)
#
# File ~/github/more-data/moredata/enricher/sql_connector/sql_connector.py:150, in SqlConnector.enrich(self, data, **kwargs)
#     <a href='file:///home/kali/github/more-data/moredata/enricher/sql_connector/sql_connector.py?line=135'>136</a> """Method overrided of interface. This method do enrichment using RDBMS
#     <a href='file:///home/kali/github/more-data/moredata/enricher/sql_connector/sql_connector.py?line=136'>137</a> as a enricher. It walk through the keys to reach at the data that will
#     <a href='file:///home/kali/github/more-data/moredata/enricher/sql_connector/sql_connector.py?line=137'>138</a> be used to create the relationship. After, if the object is a list it
#    (...)
#     <a href='file:///home/kali/github/more-data/moredata/enricher/sql_connector/sql_connector.py?line=143'>144</a> data: :obj:`Data`
#     <a href='file:///home/kali/github/more-data/moredata/enricher/sql_connector/sql_connector.py?line=144'>145</a> """
#     <a href='file:///home/kali/github/more-data/moredata/enricher/sql_connector/sql_connector.py?line=146'>147</a> if isinstance(data, GeopandasData):
#     <a href='file:///home/kali/github/more-data/moredata/enricher/sql_connector/sql_connector.py?line=147'>148</a>     # if(self.df_column == None):
#     <a href='file:///home/kali/github/more-data/moredata/enricher/sql_connector/sql_connector.py?line=148'>149</a>     #     raise Exception('df_column is required in GeopandasData')
# --> <a href='file:///home/kali/github/more-data/moredata/enricher/sql_connector/sql_connector.py?line=149'>150</a>     return self.enrichGeoPandasData(data.data)
#     <a href='file:///home/kali/github/more-data/moredata/enricher/sql_connector/sql_connector.py?line=151'>152</a> elif isinstance(data, JsonData):
#     <a href='file:///home/kali/github/more-data/moredata/enricher/sql_connector/sql_connector.py?line=152'>153</a>     return self.enrichJsonData(data, **kwargs)
#
# File ~/github/more-data/moredata/enricher/sql_connector/sql_connector.py:108, in SqlConnector.enrichGeoPandasData(self, data)
#     <a href='file:///home/kali/github/more-data/moredata/enricher/sql_connector/sql_connector.py?line=100'>101</a> def enrichGeoPandasData(self, data):
#     <a href='file:///home/kali/github/more-data/moredata/enricher/sql_connector/sql_connector.py?line=101'>102</a>     #iterar as linhas do geo pandas
#     <a href='file:///home/kali/github/more-data/moredata/enricher/sql_connector/sql_connector.py?line=102'>103</a>     #get coluna a ser enriquecida ID
#     <a href='file:///home/kali/github/more-data/moredata/enricher/sql_connector/sql_connector.py?line=103'>104</a>     #jogar na enrich object como obj
#     <a href='file:///home/kali/github/more-data/moredata/enricher/sql_connector/sql_connector.py?line=104'>105</a>     #que retorna um dict e jogar numa coluna "enriched"
#     <a href='file:///home/kali/github/more-data/moredata/enricher/sql_connector/sql_connector.py?line=105'>106</a>     #aplica o json normalize
#     <a href='file:///home/kali/github/more-data/moredata/enricher/sql_connector/sql_connector.py?line=106'>107</a>     for row in data.iterrows():
# --> <a href='file:///home/kali/github/more-data/moredata/enricher/sql_connector/sql_connector.py?line=107'>108</a>         print(self._enrich_object(row[self.column]))
#
# TypeError: tuple indices must be integers or slices, not str

# %%
data_enriched = pd.read_json("./data/airbnb-berlin-enriched-0.json", orient='records')

# %%
type(data_enriched.extra[0])
# Out:
# dict

# %%
pd.concat([data_enriched, pd.json_normalize(data_enriched['extra'], max_level=0).drop(['index', 'id'], axis=1)], axis=1)
# Out:
#              id                                               name  \
# 0          1944         bright & airy Pberg/Mitte 3 months or more
# 1          2015   Berlin-Mitte Value! Quiet courtyard/very central
# 2          3176                    Fabulous Flat in great Location
# 3          3309                  BerlinSpot Schöneberg near KaDeWe
# 4          6883  Stylish East Side Loft in Center with AC & 2 b...
# ...         ...                                                ...
# 19853  48597066  Rollstuhlgeeignete Wohnung für zwei in Hönow M...
# 19854  48599795                          Lichtdurchflutete Wohnung
# 19855  48600069                    Bright Twin Capacity 1 At Mitte
# 19856  48602039                                 One Room Apartment
# 19857  48615659           Schönes, ruhiges Zimmer am Kufürstendamm
#
#          neighbourhood    neighbourhood_cleansed        room_type      price  \
# 0      Berlin, Germany          Brunnenstr. Nord     Private room     $20.00
# 1      Berlin, Germany           Brunnenstr. Süd  Entire home/apt     $59.00
# 2      Berlin, Germany   Prenzlauer Berg Südwest  Entire home/apt     $90.00
# 3      Berlin, Germany           Schöneberg-Nord     Private room     $29.00
# 4      Berlin, Germany  Frankfurter Allee Süd FK  Entire home/apt     $79.00
# ...                ...                       ...              ...        ...
# 19853             None          Hellersdorf-Nord  Entire home/apt     $22.00
# 19854             None                 Tempelhof  Entire home/apt     $80.00
# 19855             None            Alexanderplatz     Private room  $1,840.00
# 19856             None  Frankfurter Allee Süd FK  Entire home/apt     $25.00
# 19857             None       Düsseldorfer Straße     Private room     $22.00
#
#        latitude  longitude                                              extra  \
# 0      52.54425   13.39749  {'index': 0, 'id': '1944', 'amenities': '["Dis...
# 1      52.53454   13.40256  {'index': 1, 'id': '2015', 'amenities': '["Smo...
# 2      52.53500   13.41758  {'index': 2, 'id': '3176', 'amenities': '["Ded...
# 3      52.49885   13.34906  {'index': 3, 'id': '3309', 'amenities': '["Hos...
# 4      52.51171   13.45477  {'index': 4, 'id': '6883', 'amenities': '["Smo...
# ...         ...        ...                                                ...
# 19853  52.54192   13.60749  {'index': 19854, 'id': '48597066', 'amenities'...
# 19854  52.45901   13.41783  {'index': 19855, 'id': '48599795', 'amenities'...
# 19855  52.51105   13.40680  {'index': 19856, 'id': '48600069', 'amenities'...
# 19856  52.49805   13.46587  {'index': 19857, 'id': '48602039', 'amenities'...
# 19857  52.49407   13.32443  {'index': 19858, 'id': '48615659', 'amenities'...
#
#                                                amenities  accommodates  beds  \
# 0      ["Dishes and silverware", "Kitchen", "Oven", "...           1.0   1.0
# 1      ["Smoke alarm", "Cooking basics", "Lockbox", "...           3.0   0.0
# 2      ["Dedicated workspace", "Hangers", "Kitchen", ...           4.0   2.0
# 3      ["Host greets you", "Washer", "Hangers", "Hot ...           1.0   1.0
# 4      ["Smoke alarm", "Cooking basics", "Dishes and ...           2.0   1.0
# ...                                                  ...           ...   ...
# 19853  ["Dedicated workspace", "Hangers", "Private en...           2.0   1.0
# 19854  ["Hot water kettle", "Dryer", "Hangers", "Hot ...           2.0   1.0
# 19855  ["Air conditioning", "Hot water", "Elevator", ...           1.0   1.0
# 19856  ["Dedicated workspace", "Hangers", "Kitchen", ...           1.0   NaN
# 19857  ["Dedicated workspace", "Hangers", "Kitchen", ...           2.0   NaN
#
#       bedrooms
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0
# ...        ...
# 19853      1.0
# 19854      1.0
# 19855      1.0
# 19856      1.0
# 19857      1.0
#
# [19858 rows x 13 columns]
