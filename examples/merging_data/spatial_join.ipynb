# %%
import moredata 
from moredata.models import GeopandasData

df = GeopandasData(data_file='../../moredata/datasets/airbnb-berlin.csv', data_type='csv')
data = df.from_path(df.data_file)

osm_enricher = moredata.enricher.osm.OSMPlacesConnector(place_name="Berlin, DE", files=['../osm/data/tourism.csv.gz'], radius=50, geometry_intersected=True)
data_enriched = osm_enricher.enrich(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-452df67a3341> in <module>
#       5 data = df.from_path(df.data_file)
#       6
# ----> 7 osm_enricher = moredata.enricher.osm.OSMPlacesConnector(place_name="Berlin, DE", files=[data], radius=100, geometry_intersected=True)
#       8 data_enriched = osm_enricher.enrich(data)
#
# ~/github/more-data/moredata/enricher/osm/osm_places_connector.py in __init__(self, key, value, dict_keys, place_name, files, radius, geometry_intersected, buffered)
#      75             readTemp = []
#      76             for file in self.files:
# ---> 77                 readTemp.append(pd.read_csv(file))
#      78             self._df = pd.concat(readTemp)
#      79             self._df["geometry"] = self._df["geometry"].apply(wkt.loads)
#
# ...

# %%
path = '../../moredata/datasets/airbnb-berlin.csv'
df = GeopandasData(data_file='../../moredata/datasets/airbnb-berlin.csv', data_type='csv')
df.data.tail()
# Out:
#              id                            listing_url       scrape_id  \
# 19854  48597066  https://www.airbnb.com/rooms/48597066  20210312174442
# 19855  48599795  https://www.airbnb.com/rooms/48599795  20210312174442
# 19856  48600069  https://www.airbnb.com/rooms/48600069  20210312174442
# 19857  48602039  https://www.airbnb.com/rooms/48602039  20210312174442
# 19858  48615659  https://www.airbnb.com/rooms/48615659  20210312174442
#
#       last_scraped                                               name  \
# 19854   2021-03-15  Rollstuhlgeeignete Wohnung für zwei in Hönow M...
# 19855   2021-03-15                          Lichtdurchflutete Wohnung
# 19856   2021-03-14                    Bright Twin Capacity 1 At Mitte
# 19857   2021-03-14                                 One Room Apartment
# 19858   2021-03-15           Schönes, ruhiges Zimmer am Kufürstendamm
#
#                                              description  \
# ...
